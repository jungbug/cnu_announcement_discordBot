# %%
import requests
from bs4 import BeautifulSoup
from info import urls

# %%
def get_html(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        return None

# %%
get_html(urls["board_url"])
# Out:
# '\n\n\n\n<!doctype html>\r\n<html lang="ko">\r\n\t<head>\r\n\t\t<title>학사공지 게시판목록 | 인공지능학과</title>\r\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n\t\t<meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" />\r\n\t\t<link rel="canonical" href="https://ai.cnu.ac.kr:443/ai/board/notice.do" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/_common/cms.css" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/_res/ai/_css/layout.css" />\r\n\r\n\t\t<!--[if IE 8]>\r\n\t\t<link rel="stylesheet" type="text/css" href="/_common/ie8.css" />\r\n\t\t<![endif]-->\r\n\t\t<link rel="stylesheet" type="text/css" href="/_common/css/toastr.css" />\n<link rel="stylesheet" type="text/css" href="/_common/css/jquery.ui-selectBox.css" />\n<link rel="stylesheet" type="text/css" href="/_res/board/_css/board.css" />\n<link rel="stylesheet" type="text/css" href="/_res/board/_css/type02.css" />\n<link rel="stylesheet" type="text/css" href="/_custom/cnu/resource/css/board.common.css" />\n\r\n\t\t<link rel="stylesheet" type="text/css" href="/_res/board/_css/bottom-menu.css" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/_res/ai/_css/slick.css" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/_res/ai/_css/scroll.css" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/_res/ai/_css/m-mn.css" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/_res/ai/_css/user.css" />\r\n\r\n\t\t<script type="text/javascript" src="/_common/js/jquery/jquery-1.9.1.js"></script>\r\n\t\t<script type="text/javascript" src="/_common/js/jquery/jquery-ui-1.11.4.min.js"></script>\r\n\t\t<script type="text/javascript" src="/_res/ai/_js/user/slick.min.js"></script>\r\n\t\t<script type="text/javascript" src="/_res/ai/_js/user/scroll.js"></script>\r\n\t\t<script type="text/javascript" src="/_res/ai/_js/user/visual.js"></script>\r\n\t\t<script type="text/javascript" src="/_res/ai/_js/user/m-mn.js"></script>\r\n\t\t<script defer="" type="text/javascript" src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit"></script>\r\n\t\t<link type="text/css" rel="stylesheet" charset="UTF-8" href="https://translate.googleapis.com/translate_static/css/translateelement.css">\r\n\t\t<script type="text/javascript" charset="UTF-8" src="https://translate.googleapis.com/translate_static/js/element/main_ko.js"></script>\r\n\t\t<script type="text/javascript" charset="UTF-8" src="https://translate.googleapis.com/element/TE_20181015_01/e/js/element/element_main.js"></script>\r\n\t\t<script type="text/javascript">\r\n\t\t\t//<![CDATA[\r\n\t\t\tvar _thisHost = location.protocol+\'//\'+location.host, _thisUrl = document.location.href,_so_ = false,_cur_menu_cd = \'20886\',_edit_content = false,front_page_edit = true,zooInOutMode = \'font\',_reouscePath = \'/_res/ai/\',editorVendor = \'froala\',sslYN = \'N\',sslPort = \'8443\',servicePort = \'\',developMode = false,device=\'pc\',isMobile=false,_cfgUseDevMode = false,_siteId = \'ai\',printSelector = \'#jwxe_main_content\',ctx = \'\',rootPath = \'\',locale= \'ko\',localeScriptPath=\'/_custom/cnu/resource/js/\';\r\n\t\t\t//]]>\r\n\t\t</script>\r\n\t\t<script type="text/javascript" src="/_common/cms.js"></script>\r\n\t\t<script type="text/javascript" src="/_res/board/_js/user/bottom-menu.js"></script>\r\n\t\t<script type="text/javascript" src="/_res/board/_js/user/common.js"></script>\n<script type="text/javascript" src="/_common/js/toastr.js" ></script>\n<script type="text/javascript" src="/_common/js/jquery-plugin/selectBox.min.js" ></script>\n<script type="text/javascript" src="/_custom/cnu/resource/js/board.common.js" ></script>\n<script type="text/javascript" src="/_res/board/_js/user/board.js" ></script>\n\r\n\t\t<script type="text/javascript" src="/_res/ai/_js/user.js"></script>\r\n\t</head>\r\n\t<body id="item_body" class="pc">\r\n\t\t<ul id="go_ma ...

# %%
soup = BeautifulSoup(get_html(urls["board_url"]), 'html.parser')  
notices = []
rows = soup.find_all("tr")
rows
# Out:
# [<tr>
#  <th scope="col">번호</th>
#  <th scope="col">제목</th>
#  <th scope="col">첨부</th>
#  <th scope="col">작성자</th>
#  <th scope="col">등록일</th>
#  <th class="b-no-right" scope="col">
#  					조회수
#  				</th>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519785&amp;article.offset=0&amp;articleLimit=10" title="[★★★ 1학년 교과목 수강신청 안내 (본인이 직접 수강신청) ★★★] 자세히 보기">
#
#
#  								[★★★ 1학년 교과목 수강신청 안내 (본인이 직접 수강신청) ★★★]
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.23
#  								</span>
#  <span class="hit">조회수 176</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.23</td>
#  <td class="b-no-right">
#  	                	176
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=515554&amp;article.offset=0&amp;articleLimit=10" title=" 2024 학생휴가 신청시 주의사항 안내 자세히 보기">
#
#
#  								 2024 학생휴가 신청시 주의사항 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 김현수</span>
#  <span class="b-date">
#  									24.06.11
#  								</span>
#  <span class="hit">조회수 200</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 김현수</td>
#  <td>24.06.11</td>
#  <td class="b-no-right">
#  	                	200
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=508553&amp;article.offset=0&amp;articleLimit=10" title="학과 GPU 서버 사용 신청 안내 자세히 보기">
#
#
#  								학과 GPU 서버 사용 신청 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">서무 담당 조교</span>
#  <span class="b-date">
#  									24.03.13
#  								</span>
#  <span class="hit">조회수 494</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>서무 담당 조교</td>
#  <td>24.03.13</td>
#  <td class="b-no-right">
#  	                	494
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=503557&amp;article.offset=0&amp;articleLimit=10" title="★★ 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내 자세히 보기">
#
#
#  								★★ 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.01.19
#  								</span>
#  <span class="hit">조회수 597</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.01.19</td>
#  <td class="b-no-right">
#  	                	597
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=319395&amp;article.offset=0&amp;articleLimit=10" title="[중요] 컴퓨터프로그래밍1~3, 컴퓨터구조 교과목 학과별 운영으로 개설학과 이외 수강생 전공 불인정 안내 자세히 보기">
#
#
#  								[중요] 컴퓨터프로그래밍1~3, 컴퓨터구조 교과목 학과별 운영으로 개설학과 이외 수강생 전공 불인정 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									23.01.30
#  								</span>
#  <span class="hit">조회수 1145</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>23.01.30</td>
#  <td class="b-no-right">
#  	                	1145
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=317481&amp;article.offset=0&amp;articleLimit=10" title="충남대학교 백마인턴십 수강학생 전공학점 인정 등 안내 자세히 보기">
#
#
#  								충남대학교 백마인턴십 수강학생 전공학점 인정 등 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 김현수</span>
#  <span class="b-date">
#  									23.01.03
#  								</span>
#  <span class="hit">조회수 1328</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 김현수</td>
#  <td>23.01.03</td>
#  <td class="b-no-right">
#  	                	1328
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=287509&amp;article.offset=0&amp;articleLimit=10" title="[★★★ 졸업요건]  프로젝트교과목 필수 이수 안내 자세히 보기">
#
#
#  								[★★★ 졸업요건]  프로젝트교과목 필수 이수 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									22.01.27
#  								</span>
#  <span class="hit">조회수 1596</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>22.01.27</td>
#  <td class="b-no-right">
#  	                	1596
#  	                </td>
#  </tr>,
#  <tr class="b-top-box">
#  <td class="b-num-box">
#
#
#
#
#
#
#  							공지
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=285136&amp;article.offset=0&amp;articleLimit=10" title="2022학년도 교양영어 교육과정 개편 안내(2021학년도 이전 입학자 포함) 자세히 보기">
#
#
#  								2022학년도 교양영어 교육과정 개편 안내(2021학년도 이전 입학자 포함)
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  </div>
#  <div class="b-m-con">
#  <span class="b-notice">
#  		                       			공지
#  		                       		</span>
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									21.12.30
#  								</span>
#  <span class="hit">조회수 1139</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>21.12.30</td>
#  <td class="b-no-right">
#  	                	1139
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							221
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=520413&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 1학기 교내 장학생 추가 2차 선발 (문자 수신자 확인용)  자세히 보기">
#
#
#  								2024학년도 1학기 교내 장학생 추가 2차 선발 (문자 수신자 확인용)
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 김현수</span>
#  <span class="b-date">
#  									24.07.29
#  								</span>
#  <span class="hit">조회수 107</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 김현수</td>
#  <td>24.07.29</td>
#  <td class="b-no-right">
#  	                	107
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							220
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=520389&amp;article.offset=0&amp;articleLimit=10" title="[3학년] 실무프로젝트랩3 교과목 수강 제한 안내 자세히 보기">
#
#
#  								[3학년] 실무프로젝트랩3 교과목 수강 제한 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.29
#  								</span>
#  <span class="hit">조회수 45</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.29</td>
#  <td class="b-no-right">
#  	                	45
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							219
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=520125&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 제2학기 SW교양교과목 수강 안내 자세히 보기">
#
#
#  								2024학년도 제2학기 SW교양교과목 수강 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.25
#  								</span>
#  <span class="hit">조회수 83</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.25</td>
#  <td class="b-no-right">
#  	                	83
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							218
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519935&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 제2학기 예비수강신청 계획 안내 자세히 보기">
#
#
#  								2024학년도 제2학기 예비수강신청 계획 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.24
#  								</span>
#  <span class="hit">조회수 95</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.24</td>
#  <td class="b-no-right">
#  	                	95
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							217
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519846&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 2학기 첨단분야 혁신융합대학사업(강원대주관, 인공지능학과 참여) 교류수학 안내 자세히 보기">
#
#
#  								2024학년도 2학기 첨단분야 혁신융합대학사업(강원대주관, 인공지능학과 참여) 교류수학 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.23
#  								</span>
#  <span class="hit">조회수 59</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.23</td>
#  <td class="b-no-right">
#  	                	59
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							216
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519799&amp;article.offset=0&amp;articleLimit=10" title="[수강신청관련] 컴퓨터융합학부 개설 교과목 수강신청 유의사항 안내 자세히 보기">
#
#
#  								[수강신청관련] 컴퓨터융합학부 개설 교과목 수강신청 유의사항 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.23
#  								</span>
#  <span class="hit">조회수 67</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.23</td>
#  <td class="b-no-right">
#  	                	67
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							215
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519797&amp;article.offset=0&amp;articleLimit=10" title="인공지능학과, 컴퓨터융합학부 합반 운영 교과목 안내 자세히 보기">
#
#
#  								인공지능학과, 컴퓨터융합학부 합반 운영 교과목 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.23
#  								</span>
#  <span class="hit">조회수 58</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.23</td>
#  <td class="b-no-right">
#  	                	58
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							214
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519635&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 1학기 성적경고자 상담 및 지원 프로그램 안내 자세히 보기">
#
#
#  								2024학년도 1학기 성적경고자 상담 및 지원 프로그램 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 김현수</span>
#  <span class="b-date">
#  									24.07.23
#  								</span>
#  <span class="hit">조회수 38</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 김현수</td>
#  <td>24.07.23</td>
#  <td class="b-no-right">
#  	                	38
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							213
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519612&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 제2학기 수강신청 기본 계획 안내 자세히 보기">
#
#
#  								2024학년도 제2학기 수강신청 기본 계획 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-new">
#  <span>N</span>
#  </p>
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 이희정</span>
#  <span class="b-date">
#  									24.07.22
#  								</span>
#  <span class="hit">조회수 129</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 이희정</td>
#  <td>24.07.22</td>
#  <td class="b-no-right">
#  	                	129
#  	                </td>
#  </tr>,
#  <tr class="">
#  <td class="b-num-box">
#
#
#
#
#  							212
#
#
#
#
#  					</td>
#  <td class="b-td-left">
#  <div class="b-title-box">
#  <a href="?mode=view&amp;articleNo=519357&amp;article.offset=0&amp;articleLimit=10" title="2024학년도 제2학기 휴학 및 복학 신청 안내  자세히 보기">
#
#
#  								2024학년도 제2학기 휴학 및 복학 신청 안내
#
#
#
#
#  							</a>
#  <div class="b-etc-box">
#  <p class="b-file b-zip">
#  <span>zip</span>
#  </p>
#  </div>
#  <div class="b-m-con">
#  <span class="b-writer">조교 김현수</span>
#  <span class="b-date">
#  									24.07.19
#  								</span>
#  <span class="hit">조회수 56</span>
#  <span class="b-file">첨부파일</span>
#  </div>
#  </div>
#  </td>
#  <td>
#  <div class="b-file-box">
#  <span class="hide">첨부파일</span>
#  </div>
#  </td>
#  <td>조교 김현수</td>
#  <td>24.07.19</td>
#  <td class="b-no-right">
#  	                	56
#  	                </td>
#  </tr>]

# %%
for row in rows:
    number = row.find('td', class_ = "b-num-box")
    title_box =row.find('div', class_ = "b-title-box")
    date = row.find('span', class_ = "b-date")
    writer = row.find('span', class_ = "b-writer")
    views = row.find('span', class_ = "hit")
    notice_data = {'번호': number.get_text(strip=True) if number else '',
                   '제목': title_box.a.get_text(strip=True) if title_box and title_box.a else '',
                   "작성자" : writer.get_text(strip=True) if writer else '', 
                   '날짜': date.get_text(strip=True) if writer else '',
                   "조회수": views.get_text(strip=True) if views else '',
                   "본문링크": urls["board_url"] + title_box.a['href'] if title_box and title_box.a else ''}
    notices.append(notice_data)
notices
# Out:
# [{'번호': '', '제목': '', '작성자': '', '날짜': '', '조회수': '', '본문링크': ''},
#  {'번호': '공지',
#   '제목': '[★★★ 1학년 교과목 수강신청 안내 (본인이 직접 수강신청) ★★★]',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '조회수 176',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519785&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '2024 학생휴가 신청시 주의사항 안내',
#   '작성자': '조교 김현수',
#   '날짜': '24.06.11',
#   '조회수': '조회수 200',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=515554&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '학과 GPU 서버 사용 신청 안내',
#   '작성자': '서무 담당 조교',
#   '날짜': '24.03.13',
#   '조회수': '조회수 494',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=508553&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '★★ 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.01.19',
#   '조회수': '조회수 597',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=503557&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '[중요] 컴퓨터프로그래밍1~3, 컴퓨터구조 교과목 학과별 운영으로 개설학과 이외 수강생 전공 불인정 안내',
#   '작성자': '조교 이희정',
#   '날짜': '23.01.30',
#   '조회수': '조회수 1145',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=319395&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '충남대학교 백마인턴십 수강학생 전공학점 인정 등 안내',
#   '작성자': '조교 김현수',
#   '날짜': '23.01.03',
#   '조회수': '조회수 1328',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=317481&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '[★★★ 졸업요건]  프로젝트교과목 필수 이수 안내',
#   '작성자': '조교 이희정',
#   '날짜': '22.01.27',
#   '조회수': '조회수 1596',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=287509&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '2022학년도 교양영어 교육과정 개편 안내(2021학년도 이전 입학자 포함)',
#   '작성자': '조교 이희정',
#   '날짜': '21.12.30',
#   '조회수': '조회수 1139',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=285136&article.offset=0&articleLimit=10'},
#  {'번호': '221',
#   '제목': '2024학년도 1학기 교내 장학생 추가 2차 선발 (문자 수신자 확인용)',
#   '작성자': '조교 김현수',
#   '날짜': '24.07.29',
#   '조회수': '조회수 107',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520413&article.offset=0&articleLimit=10'},
#  {'번호': '220',
#   '제목': '[3학년] 실무프로젝트랩3 교과목 수강 제한 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.29',
#   '조회수': '조회수 45',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520389&article.offset=0&articleLimit=10'},
#  {'번호': '219',
#   '제목': '2024학년도 제2학기 SW교양교과목 수강 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.25',
#   '조회수': '조회수 83',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520125&article.offset=0&articleLimit=10'},
#  {'번호': '218',
#   '제목': '2024학년도 제2학기 예비수강신청 계획 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.24',
#   '조회수': '조회수 95',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519935&article.offset=0&articleLimit=10'},
#  {'번호': '217',
#   '제목': '2024학년도 2학기 첨단분야 혁신융합대학사업(강원대주관, 인공지능학과 참여) 교류수학 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '조회수 59',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519846&article.offset=0&articleLimit=10'},
#  {'번호': '216',
#   '제목': '[수강신청관련] 컴퓨터융합학부 개설 교과목 수강신청 유의사항 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '조회수 67',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519799&article.offset=0&articleLimit=10'},
#  {'번호': '215',
#   '제목': '인공지능학과, 컴퓨터융합학부 합반 운영 교과목 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '조회수 58',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519797&article.offset=0&articleLimit=10'},
#  {'번호': '214',
#   '제목': '2024학년도 1학기 성적경고자 상담 및 지원 프로그램 안내',
#   '작성자': '조교 김현수',
#   '날짜': '24.07.23',
#   '조회수': '조회수 38',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519635&article.offset=0&articleLimit=10'},
#  {'번호': '213',
#   '제목': '2024학년도 제2학기 수강신청 기본 계획 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.22',
#   '조회수': '조회수 129',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519612&article.offset=0&articleLimit=10'},
#  {'번호': '212',
#   '제목': '2024학년도 제2학기 휴학 및 복학 신청 안내',
#   '작성자': '조교 김현수',
#   '날짜': '24.07.19',
#   '조회수': '조회수 56',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519357&article.offset=0&articleLimit=10'}]

# %%
def clean_data(notices):
    notices.pop(0)
    for notice in notices:
        view = notice["조회수"].replace("조회수", "").strip()
        notice["조회수"] = view
    return notices
posts = clean_data(notices)
posts
# Out:
# [{'번호': '공지',
#   '제목': '[★★★ 1학년 교과목 수강신청 안내 (본인이 직접 수강신청) ★★★]',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '176',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519785&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '2024 학생휴가 신청시 주의사항 안내',
#   '작성자': '조교 김현수',
#   '날짜': '24.06.11',
#   '조회수': '200',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=515554&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '학과 GPU 서버 사용 신청 안내',
#   '작성자': '서무 담당 조교',
#   '날짜': '24.03.13',
#   '조회수': '494',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=508553&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '★★ 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.01.19',
#   '조회수': '597',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=503557&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '[중요] 컴퓨터프로그래밍1~3, 컴퓨터구조 교과목 학과별 운영으로 개설학과 이외 수강생 전공 불인정 안내',
#   '작성자': '조교 이희정',
#   '날짜': '23.01.30',
#   '조회수': '1145',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=319395&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '충남대학교 백마인턴십 수강학생 전공학점 인정 등 안내',
#   '작성자': '조교 김현수',
#   '날짜': '23.01.03',
#   '조회수': '1328',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=317481&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '[★★★ 졸업요건]  프로젝트교과목 필수 이수 안내',
#   '작성자': '조교 이희정',
#   '날짜': '22.01.27',
#   '조회수': '1596',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=287509&article.offset=0&articleLimit=10'},
#  {'번호': '공지',
#   '제목': '2022학년도 교양영어 교육과정 개편 안내(2021학년도 이전 입학자 포함)',
#   '작성자': '조교 이희정',
#   '날짜': '21.12.30',
#   '조회수': '1139',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=285136&article.offset=0&articleLimit=10'},
#  {'번호': '221',
#   '제목': '2024학년도 1학기 교내 장학생 추가 2차 선발 (문자 수신자 확인용)',
#   '작성자': '조교 김현수',
#   '날짜': '24.07.29',
#   '조회수': '107',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520413&article.offset=0&articleLimit=10'},
#  {'번호': '220',
#   '제목': '[3학년] 실무프로젝트랩3 교과목 수강 제한 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.29',
#   '조회수': '45',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520389&article.offset=0&articleLimit=10'},
#  {'번호': '219',
#   '제목': '2024학년도 제2학기 SW교양교과목 수강 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.25',
#   '조회수': '83',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520125&article.offset=0&articleLimit=10'},
#  {'번호': '218',
#   '제목': '2024학년도 제2학기 예비수강신청 계획 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.24',
#   '조회수': '95',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519935&article.offset=0&articleLimit=10'},
#  {'번호': '217',
#   '제목': '2024학년도 2학기 첨단분야 혁신융합대학사업(강원대주관, 인공지능학과 참여) 교류수학 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '59',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519846&article.offset=0&articleLimit=10'},
#  {'번호': '216',
#   '제목': '[수강신청관련] 컴퓨터융합학부 개설 교과목 수강신청 유의사항 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '67',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519799&article.offset=0&articleLimit=10'},
#  {'번호': '215',
#   '제목': '인공지능학과, 컴퓨터융합학부 합반 운영 교과목 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.23',
#   '조회수': '58',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519797&article.offset=0&articleLimit=10'},
#  {'번호': '214',
#   '제목': '2024학년도 1학기 성적경고자 상담 및 지원 프로그램 안내',
#   '작성자': '조교 김현수',
#   '날짜': '24.07.23',
#   '조회수': '38',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519635&article.offset=0&articleLimit=10'},
#  {'번호': '213',
#   '제목': '2024학년도 제2학기 수강신청 기본 계획 안내',
#   '작성자': '조교 이희정',
#   '날짜': '24.07.22',
#   '조회수': '129',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519612&article.offset=0&articleLimit=10'},
#  {'번호': '212',
#   '제목': '2024학년도 제2학기 휴학 및 복학 신청 안내',
#   '작성자': '조교 김현수',
#   '날짜': '24.07.19',
#   '조회수': '56',
#   '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519357&article.offset=0&articleLimit=10'}]

# %%
for post in posts:
    post_url = post["본문링크"]
    soup = BeautifulSoup(get_html(post_url), 'html.parser')
    trs = soup.find_all("tr")
    for tr in trs:
        contents = tr.find("div", class_="fr-view")
        print((post["번호"]+": "+ contents.get_text(strip=True)).strip()) if contents else ''
# Out:
# 공지: 1학년 수강신청 날짜 및 시간을 꼭 확인 하시고 아래 안내 사항 확인 후본인이 직접 수강신청하시기 바랍니다. (2학기부터는 학과에서 수강신청 해주지 않음)[1학년 수강 신청 교과목]이수구분교과목명교과목번호분반학점졸업요건수강신청 기간교양미적분학11151-7008003필수1학년 수강신청 기간8. 6.(화) 15:00～17:00인공지능과 미래사회1004-7003053필수전공선형대수1214-1003003필수어드벤처디자인1215-1002003필수컴퓨터프로그래밍21216-1002003필수본인이 교양에서1개 교과목 선택해서 수강신청*3예비 수강신청 기간7.29(월)~7.31(수) 09:00~18:00-본인이 교양에서1개 교과목 선택해서 수강신청*:한 학기 수강 학점은 총18학점으로 학과에서 지정한 교과목(15학점)외에나머지3학점은 교양 교과목에서 본인이 희망하는 교과목으로 수강신청,될 수 있으면 졸업 필수 교과목인 핵심교양(목록은 붙임 졸업요건에서 확인)으로 수강 신청-인공지능과미래사회: 2022학번부터 지정된 전문기초교양으로2021학번은 인공지능개론(분반 상관없음.)수강 해야 함.-미적분학1: 2023학번부터 필수, 2021~2022학번은 선택(본인학번의 졸업요건 확인)[유의사항 및 일정]1.미적분학1,인공지능과미래사회:지정된 분반은 인공지능학과 학생을 위하여 확보된 분반이지만 타과 학생이 수강신청 할 경우 여석 확보가 어려울 수 있으므로가급적 빨리(8. 6.(화) 15:00정원 열리자마자)수강신청 하여 주시기 바랍니다.2.예비수강신청: 7.29(월) ~ 7.31.(수) 09:00~18:00 (학과에서 지정한 위의5개 교과목은 예비수강신청 대상과목이 아님)3.수강신청기간: 8.5(월) ~ 8.9(금)4. 1학년 수강신청 기간: 8.6(화) 15:00 ~ 17:00[해당 공지사항 문의: 821-7456,담당조교:이희정]
# 공지:
# 공지: 학과에서는 연구용  GPU 사용 신청이 필요한 학생들에게 개발 환경을 제공하고 있습니다.아래 링크로 신청 하여 주시고 매뉴얼도 꼭 읽어 보시기 바랍니다.[구글신청폼 링크] : https://forms.gle/eeDHBbeXztzEEAkm8
# 공지: 2024학년도 교육과정 개편으로 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내 드립니다.1. 인공지능개론 교과목의 대체 교과목 (해당학번: 2021)-　전문기초교양 교과목은 본인의 이후 교육과정에 있는 교과목을 이수할 경우 전문기초교양으로 인정받을 수 있으니 인공지능개론 교과목 수강이 어려운 학생은 2022학년도 이후 교육과정의 전문기초교양 교과목인 인공지능과미래사회 교과목을 수강하시기 바랍니다.2.  컴퓨터과학적사고 교과목 이수면제 (해당학번: 2021~2023)- 컴퓨터과학적사고 교과목이 2024학년도 교육과정 개편으로 교양(전문기초교양)에서 지정 해지 되어 이전 교육과정 적용자(2018~2023) 모두 이수면제 처리 되었습니다.이수면제된 학점은 교양(핵심, 일반)과목으로 추가 이수하여 교양 졸업학점을 채우면 됩니다.
# 공지: 2023학년도 1학기부터 개설되는 아래 교과목은 컴퓨터융합학부와 교과목명은 동일하나교과목번호를 다르게 지정하여 학과별로 교육내용을 차별화하여 교과목을 운영하여개설학과 이외 학생이 수강할 경우 전공으로 인정 받을 수 없으니아래교과목은 반드시 본인의 소속학과에 개설된 교과목만 수강신청 하시기 바랍니다.이외에 컴퓨터융합학부와 인공지능학과에 개설된 교과목 중  교과목명 및 교과목번호가 같은 교과목은  두 학과 학생 모두 전공으로 인정 받습니다.2021, 2022학번 중 위의 교과목을 이수하지 않은 학생은2023년 이후에 인공지능학과에 개설 된  교과목을 수강하시면 됩니다.(본인의 교육과정 적용년도에 교과목번호가 달라도 인공지능학과에 개설된 교과목은  인공지능학과 학생이 수강할 경우 전공으로 인정 됨)
# 공지: □ 백마인턴십: 충남대학교와 사회의 각 기업(관)이 공동으로 참여하여 산업체 현장에서 학생에게 실무교육 및 실습을 실시하는 산학협력 교육과정자세한 내용은 붙임문서로 꼭 확인하기 바랍니다.* 복수전공. 부전공하는 타과 학생은 백마인턴십을 전공으로 인정하지 않습니다.전공 수업을 통해 학점을 채우기 바랍니다.* 우리 학과(컴융. 인공)학생이 컴융. 인공지능학과를 상호 복수.부전공 할 경우 백마인턴십을 복수.부전공으로 인정하지 않습니다.  주전공에서만 전공학점으로 인정합니다.가. 교과과정* 졸업을 위한 학점인정을 계획하는 경우, 계절학기 백마인턴은 3학점만 신청가능.교과목명실습기간인정학점백마인턴십 Ⅲ-1, Ⅲ-2, Ⅲ-3, Ⅲ-44주3학점백마인턴십 Ⅰ-1, Ⅰ-2, Ⅰ-38주6학점백마인턴십II1학기18학점□ 실습시간 및 장소ㅇ 실습일수: 실제 출근일이 4주 20일, 8주 40일, 학기제 일 8시간 75일(주40시간 이내)이 되도록 실습 수행※실습일수 미충족 시 학생 학점 이수 불가※ 과정은 실습기관별 연말·연시 휴일을 반영하여 종료일 설정□ 백마인턴십 담당 선생님: 821-6169나. 참여대상 : 신청일 기준 4학기 이상 이수한 재학생 및 휴학생다. 신청방법 : 통합정보시스템-인턴십신청* 컴퓨터융합학부. 인공지능학과 전공자에 한하여 전공학점 인정되는 경우는- 1회에 한하여 인정(1회가 18학점 학기제이든 6학점 또는 3학점 계절제이든 1회만 인정)- 6학점 계절제 백마인턴십을 2번 이수하여도 1회(6학점)만 인정. 합산 불가- 6개 학기 학점사정, 졸업 사정 등에서 담당 선생님이 이수구분 정정함.- 부복수전공을 이수하는 타학과 학생이 컴퓨터관련 인턴십을 하여도 부복수이수학점으로 인정되지 않음.(본인 소속의 전공으로 인정되는지는 소속학과에 문의 필수)- 소프트웨어중심대학 사업단에서 백마인턴십과 함께 추진하여 인턴십 등으로 연계할 경우, 최대 24학점 인정.매학기 공지되는 백마인턴십 운영계획을 잘 확인하고 신청하기 바랍니다.
# 공지: 인공지능학과 내규에 따른2021학년도 이후 입학자(교육과정적용연도포함)들의 졸업요건에 해당되는 사항입니다. (2021학년도 입학자 포함)1. 프로젝트 교과목 필수 이수- 인공지능학과 학생은모든 프로젝트 교과목 의무 수강을 통하여 최소한 1년에 1건 이상의 팀 프로젝트를 수행하여 졸업시까지 최소 3건 이상의 실무 프로젝트를 수행 하는 것을 목적으로 한다(졸업요건: 1년에 1개 교과목 이상 이수, 최소 3개 교과목 이수 완료)교과목명개설 학년-학기어드벤처디자인1-2기초프로젝트랩2-1, 2-2심화프로젝트랩3-1, 3-2종합설계14-1종합설계24-2
# 공지:
# 221: 2024학년도 1학기 장학생 선발 후 국가장학금 등 기타 장학으로 변경되어, 교내 장학 예산이 남게되면 추가 장학생을 선발합니다.1. 대상: 재학생 중 학과 기준에 따라 선발휴학생 중 등록금 납부자 중 기준에 따라 선발2. 선발결과: 학과 별 배정인원에 따라 선발하고, 대상자에게 문자 안내함본 공지사항은 문자 수신자가 스미싱 문자가 아님을 확인해주기 위한 공지입니다.추가 선발을 위한 신청은 받지 않습니다.본인 계좌 확인되면 본 공지는 삭제함
# 220: 실무프로젝트랩3 교과목은 기업 연계 교과목으로수강신청 대상자는 카카오테크 캠퍼스 3기 학생 또는 CNU SW아카데미 5기 참여 학생입니다.2024학년도 2학기부터 수강신청 방법 또한기존 학과 일괄 수강신청에서 학생 직접(개별) 수강신청,학과 수강취소에서 학생 직접(개별) 수강취소로 변경되었으니 참고하여 주시기 바랍니다.
# 219: 소프트웨어중심대학사업단에서는 대학SW·AI교육을 통한 융합인재 양성을 위해SW기초 역량 교육을 아래와 같이 제공하고 있습니다.컴퓨터융합학부 및 인공지능학과 학생은인공지능과미래사회(03~05분반),파이썬 프로그래밍,인공지능융합기초 교과목을 제외한 나머지 교과목은 수강 불가로수강신청 시 유의 하시기 바랍니다.해당 과목 외 수강신청 기간에 수강신청이 가능하여 수강신청 했더라도개강 시 담당교수님의 수강 제한이 있으니 참고하시기 바랍니다.2024학년도 2학기 SW교양교과목 운영 계획과목명(과목번호)분반수강신청 대상비고컴퓨터과학적사고(1004-7002)00~03전계열(권장계열 : 이공계열)이론(콘텐츠 활용) + 실습(실시간 원격, 파이썬기초)인공지능과 미래사회(1004-7003)00~02전계열콘텐츠 활용 원격 강의시간표 미지정03~05컴퓨터융합학부,인공지능학과 전용 분반인공지능융합기초(1004-7004)00~02전계열대면 강의파이썬 프로그래밍(1004-7005)00~01전계열이론(콘텐츠 활용) + 실습(실시간 원격)02전계열대면 강의데이터분석 입문과활용(1004-7006)00전계열이론(콘텐츠 활용) + 실습(실시간 원격)컴퓨터 이해와 활용(1004-7007)00전계열(권장계열 : 인문/사회/예체능)대면 강의01~03전계열(권장계열 : 인문/사회/예체능)콘텐츠 활용 원격 강의,시간표 미지정04전계열콘텐츠 활용 원격 강의시간표 미지정(외국인 전용 분반)정보보호 입문과활용(1004-7008)00전계열대면 강의웹프로그래밍기초(1004-7009)00전계열이론(콘텐츠 활용) + 실습(실시간 원격)C프로그래밍기초(1004-7010)00전계열이론(콘텐츠 활용) + 실습(실시간 원격)※ 「컴퓨터 이해와 활용」, 「인공지능과 미래사회」 교과목 등 일부 분반은 1학년 수강 정원 비율을 높여 운영□ 소프트웨어중심대학사업단 주관 SW교양교과목 강좌 운영 계획수강 제한 사항- 파이썬프로그래밍, 웹프로그래밍기초, C프로그래밍기초 : 프로그래밍 관련 타 교과목에서 해당 프로그래밍 언어를 배운 학생은 수강 불가- 컴퓨터융합학부, 인공지능학과 : 인공지능과 미래사회(03~05분반), 파이썬 프로그래밍, 인공지능융합기초 교과목 외 수강 불가운영방법 : 대면강의/원격강의(실시간/콘텐츠활용) 등 교과목별로 상이평가방법 : 절대평가
# 219: 소프트웨어중심대학사업단에서는 대학SW·AI교육을 통한 융합인재 양성을 위해SW기초 역량 교육을 아래와 같이 제공하고 있습니다.컴퓨터융합학부 및 인공지능학과 학생은인공지능과미래사회(03~05분반),파이썬 프로그래밍,인공지능융합기초 교과목을 제외한 나머지 교과목은 수강 불가로수강신청 시 유의 하시기 바랍니다.해당 과목 외 수강신청 기간에 수강신청이 가능하여 수강신청 했더라도개강 시 담당교수님의 수강 제한이 있으니 참고하시기 바랍니다.2024학년도 2학기 SW교양교과목 운영 계획과목명(과목번호)분반수강신청 대상비고컴퓨터과학적사고(1004-7002)00~03전계열(권장계열 : 이공계열)이론(콘텐츠 활용) + 실습(실시간 원격, 파이썬기초)인공지능과 미래사회(1004-7003)00~02전계열콘텐츠 활용 원격 강의시간표 미지정03~05컴퓨터융합학부,인공지능학과 전용 분반인공지능융합기초(1004-7004)00~02전계열대면 강의파이썬 프로그래밍(1004-7005)00~01전계열이론(콘텐츠 활용) + 실습(실시간 원격)02전계열대면 강의데이터분석 입문과활용(1004-7006)00전계열이론(콘텐츠 활용) + 실습(실시간 원격)컴퓨터 이해와 활용(1004-7007)00전계열(권장계열 : 인문/사회/예체능)대면 강의01~03전계열(권장계열 : 인문/사회/예체능)콘텐츠 활용 원격 강의,시간표 미지정04전계열콘텐츠 활용 원격 강의시간표 미지정(외국인 전용 분반)정보보호 입문과활용(1004-7008)00전계열대면 강의웹프로그래밍기초(1004-7009)00전계열이론(콘텐츠 활용) + 실습(실시간 원격)C프로그래밍기초(1004-7010)00전계열이론(콘텐츠 활용) + 실습(실시간 원격)※ 「컴퓨터 이해와 활용」, 「인공지능과 미래사회」 교과목 등 일부 분반은 1학년 수강 정원 비율을 높여 운영□ 소프트웨어중심대학사업단 주관 SW교양교과목 강좌 운영 계획수강 제한 사항- 파이썬프로그래밍, 웹프로그래밍기초, C프로그래밍기초 : 프로그래밍 관련 타 교과목에서 해당 프로그래밍 언어를 배운 학생은 수강 불가- 컴퓨터융합학부, 인공지능학과 : 인공지능과 미래사회(03~05분반), 파이썬 프로그래밍, 인공지능융합기초 교과목 외 수강 불가운영방법 : 대면강의/원격강의(실시간/콘텐츠활용) 등 교과목별로 상이평가방법 : 절대평가
# 218: [중요]컴퓨터융합학부 및 인공지능학과에 개설된 모든 전공 교과목은예비수강신청 - 우선확정(구. 밀어주기) 대상 교과목이 아닙니다. ( 우선확정 기능 안됨)전 학년, 모든 학과 학생들에게 오픈 되어지는 예비수강신청의 특성상수강대상 인원이 많은 우리 학과의 특성을 고려하여 우선확정 대상 과목이 없음을 안내 드립니다.ㅊ2024학년도 제2학기 예비수강신청 안내▸예비수강신청이란?과목별 정원 없이개인별 최대 수강신청 학점 범위 내에서신청하고자 하는 과목을쇼핑몰 장바구니처럼 담아두어본 수강신청 시 신속하게 진행할 수 있는 제도□ 운영 개요○ 대상:재학생[학부 및 대학원(일반,전문,특수)],휴학생(복학예정자)※ 단, 2024학년도 1학기 기준 신입생 및 편입생은 제외○ 기간:2024. 7. 29.(월) 09:00 ~ 7. 31.(수) 18:00○ 대상강좌: 2024학년도 제2학기 개설 교과목 전체○ 수강신청 방법:수강신청시스템(https://sugang.cnu.ac.kr/)→ 로그인 →‘예비수강신청 화면으로 이동’클릭(또는 수강관리 → 예비수강신청)※ 컴퓨터(웹)로만 수강신청 가능○ 예비수강신청 내역 확인:수강신청시스템- ‘예비수강신청내역조회’○ 유의사항[중요★]-‘우선확정’(구.밀어주기)과목을 제외한 그 외 과목은실제 수강신청이 되거나 우선순위가 보장되는 것이 아니므로반드시본 수강신청 기간에 별도 신청 필요-예비수강신청 이후 강의일람(담당 교원,시간표,강의실 등)이 변경될 수 있으니본 수강신청 전 수강일람(시간표 등)재확인□ 예비수강신청 「우선확정」(구. 밀어주기)안내○‘우선확정’이란?- ‘우선확정’대상 과목 중,예비수강신청 기간 종료 후우선확정 수강정원 내로수강신청된 과목은일괄 수강 확정 처리하는 제도※ 학생은 본 수강신청 시 별도로 수강신청할 필요 없음※ ‘밀어주기’에서 이해하기 쉬운 용어로 변경(΄24. 1학기~)○ 대상 과목: 4차산업혁명시대를위한인문학입문 등598강좌[붙임2참조]○‘우선확정’결과(일괄 수강신청 처리)개별 확인-확인 방법: 2024. 8. 1.(목) 18:00이후 통합정보시스템- ‘수강신청내역 조회’→‘수강내역’확인(확정된 경우 수강내역에 해당 과목이 확인됨)○ 유의사항:수강정원이초과되어 수강신청이 확정되지 않은 경우본 수강신청 기간 선착순으로 수강신청을 하여야 수강신청이확정됨□ 예비 수강신청 관련 FAQQ1. 예비수강신청을 하면 수강신청이 확정되는 건가요?A1.아닙니다!!본 수강신청 때 선착순으로 정원 내‘확정하기’버튼을 누른 경우에 수강신청이 확정됩니다.※ 단, 정원 내 ‘우선확정’으로 수강신청 확정된 과목은 제외(상단 참조)Q2. 실제 수강신청 시 예비수강신청을 신청한 과목만 신청이 되나요?A2. 아닙니다.본 수강 신청 때 예비수강을 신청하지 않은 과목도 신청 가능합니다.Q3. 예비수강신청은 반드시 해야 하나요?A3. 아닙니다. 개인 선택사항입니다.Q4. 예비수강신청에서 담아놓은 과목의 강의일람(강의시간, 강의실, 교수)이 바뀔 수 있나요?A4. 개설학과 사정에 따라 본 수강신청 시 변경될 수 있습니다.반드시 본 수강신청 전 강의시간과 강의실을 확인해 주시기 바랍니다.Q5. ‘우선확정’대상 과목 중 정원이 초과되었습니다. 본 수강신청 때 선착순으로 예비수강신청한 순서로 확정되나요?A5. 아닙니다.본 수강신청 기간 동안에 선착순으로 수강 신청한 순서로 확정됩니다.Q6. 예비수강신청도 선착순으로 신청해야하나요?A6. 아닙니다.‘우선확정’과목도 예비수강신청 기간 종료 후, 최종 정원으로 판단하기 때문에 선착순으로 하지 않아도 됩니다.Q7. ‘우선확정’으로 확정된 경우 본 수강신청 때 취소가 가능한가요?A7. 가능합니다.본 수강신청 기간 동안 수강신청 화면에서 수강신청 내역에 있는 과목 중 앞에 ‘삭제’ 버튼을 누르면 취소됩니다.
# 217: 충남대학교 인공지능학과 및 컴퓨터융합학부가 참여하는첨단분야 혁신융합대학사업(강원대 주관)에서 아래와 같이 학점교류  수학을 안내하오니많은 학생의 참여 바랍니다.1. 신청자격:데이터보안.활용융합 분야 마이크로 디그리과정 진입 및 이수를 희망하는 학생2. 신청절차1) 충남대학교포털(http://portal.cnu.ac.kr)ID(학번)비밀번호통합정보시스템 교외활동신청타대학학점교류신청신청서 작성2) 수학신청서 제출: 교과목 제공학과 날인 후 학생이 소속 학과로 직접 제출※ 신청 교과목 취소 및 변경 사항이 있는 경우 반드시 변경원 제출3. 제출서류1) 다른 대학 수학신청서(통합정보시스템 출력분) 1부2) 다른 대학 수학신청서(붙임4, 휴학자용-2024.1학기 복학예정자) 1부3) 추천서 (붙임2) 1부 (학생 개인정보만 작성, 추천 내용은 학과에서 작성)4) 개인정보수집및이용동의서(붙임10) 1부5) 강원대학교 수학신청서(붙임7)4. 기타: 해당 과목을 포함한 마이크로디그리 안내(2학기 중 진행 예정)붙임 1. 2024학년도 2학기 첨단분야 혁신융합대학사업(강원대) 공문 1부.2. 추천서 1부.3. 개인정보 수집 및 이용사항 고지 안내문 1부.4. 다른 대학 수학 신청서(휴학자용-2024.2학기 복학예정자) 1부.5. 2024학년도 2학기 강원대학교 수학 안내문(타대학에서 강원대학교로) 1부.6. 2024학년도 2학기 학점교류 수강신청(강원대학교) 안내 1부.7. 2024학년도 2학기 학점교류 추천자 명단 1부.8. 2024학년도 2학기 학점교류 변경 및 취소 사유서 1부.9. 2024학년도 2학기 교과목 운영 내역 1부.10. 2024학년도 2학기 개인정보수집및이용동의서 1부. 끝.
# 216: 원칙적으로 컴퓨터융합학부와 인공지능학과는 다른 학과로 교과목번호가 같더라도본인 소속이 아닌 학과의 수업을 수강하면 일선으로 인정됩니다.컴퓨터융합학부 소속 학생은 컴퓨터융합학부 개설 교과목을인공지능학과 소속 학생은 인공지능학과 개설 교과목을 수강하시기 바랍니다.단교과목번호가 동일한교과목 중교육내용이 같고,학년이 같은 교과목 중타과 학생의 수강을 꼭 허용해야 하는 교과목이라면소속 학생의 수강신청이 완료 된 후8월 9일(금) 오전10시 수강을 허용할 예정입니다.자세한 내용(교과목, 허용 인원, 수강 가능 대상 학생 등)은 8월 8일(목) 오후 3시에안내 될 예정입니다.타과 수강신청이 가능하여 수강했더라도개강 시 담당교수님의 수강 제한이 있을 수 있으니 참고하시기 바랍니다.(학과에서 허용한 교과목 제외)문의전화: 042-821-7456 (수강신청에 대한 메일 상담은 하지 않습니다.이점 양해 바랍니다.)문의시간: 09:00 ~ 17:00
# 215: 교과목 특성으로 아래 교과목은 인공지능학과, 컴퓨터융합학부 합반하여 운영합니다.인공지능학과, 컴퓨터융합학부생 모두 전공으로 인정되며두 학과 부,복수전공생도 모두 부,복수전공학점으로 인정 받습니다.단 종합설계2는 개설 학점 제한으로 컴퓨터융합학부에 개설되었으니 수강신청 희망하는 4학년 학생은 학과사무실로 연락 주시가 바랍니다.[해당 공지사항 문의: 821-7456,담당조교:이희정]
# 215: 교과목 특성으로 아래 교과목은 인공지능학과, 컴퓨터융합학부 합반하여 운영합니다.인공지능학과, 컴퓨터융합학부생 모두 전공으로 인정되며두 학과 부,복수전공생도 모두 부,복수전공학점으로 인정 받습니다.
# 214: 2024학년도 1학기 성적이 1.75 미만인 학생은 성적경고대상자이며,아래 내용을 숙지하여 관련 서류 제출 및 상담을 진행하기 바랍니다.* 2020학번부터는 연속 3회, 통상 5회 성적경고시 제적이며, 제적일자 기준 1년 뒤 재입학 가능재입학 후에도 성적경고로 제적시 재입학 제한될 수 있음.충남대학교 성적경고자 지원 프로그램 안내문본교의 성적경고자 학점제한 제도가 실시됨에 따라, 2024학년도 1학기에 성적경고를 받은 학생들은아래 프로그램 절차를 수료시에만 성적경고로 제한받은 3학점을 신청할 수 있음을 안내드립니다.(※2024학년도 1학기에 성적경고를 받고2024학년도 2학기에 재학하는 학생에 한함.)* 프로그램은 첨부문서로 확인[ 성적 경고 학생이 기간 내 반드시 해야할 일 ]1.  학업증진계획서 제출: 9월 9일(월)까지 (구글폼:https://forms.gle/q9pca3uUD7BUBKsN8)(양식: 자료실링크클릭)기간 내 미제출 학생은 부모님께 통화 및 가정 안내문 발송 예정2. 지도교수 상담: 9월 9일~9월 13일(금)까지 상담 신청, 9월 23일까지 상담 완료  -> 상담후 교수님이 상담결과를 학과로 제출 -> 상담 결과를 공대학장님에게 제출* 미래설계상담 수강자는 미래설계상담 신청을 통해 진행해도 됨미래설계상담 교수님은 수강신청 종료된 다음날 공지사항에 안내됨.* 미래설계상담 미수강자는 9월 9일 본 공지 하단에 지도교수 추가 함.(2024학년도 1학기 미래설계상담 교수님과 동일함)교수님께 개별로 이메일을 보내 상담 신청상담신청시 미래설계상담이 아닌 성적관련 일반 상담임을 미리 말씀드리면 됩니다.대상 교수님에겐 미리 안내되어 학생 연락을 기다리고 있습니다.3. 본인확인서에 사인: 9월 23일(월)까지학과사무실에 방문하여 본인 확인서에 사인(9월 1일 기준 자퇴자, 휴학자(8월 1일~8월 31일)는 본인 확인을 위한 방문 및 상담 대상이 아님)4. 지도교수 상담 및 제출서류 문의: 042-821-6651(학과사무실)[미래설계상담 미수강자 지도교수 명단] - 9월 9일에 하단에 공지함.
# 213: 2024학년도 제2학기 수강신청 기본 계획을 붙임과 같이 알려드립니다.가. 수강신청 기간:2024. 8. 5.(월) ~ 8. 9.(금)※ 예비수강신청 기간: 2024. 7. 29.(월) ～ 7. 31.(수)※ 수강신청 변경 기간: 2024. 9. 2.(월) ～ 9. 6.(금)나. 수강신청 방법: 수강신청시스템에서 개별 신청(홈페이지에 바로가기 설치 예정)- 재학생(휴학생, 재입학생 포함):https://sugang.cnu.ac.kr- 신입생(외국인, 시간제등록생 포함):https://sugang.cnu.ac.kr/Flogin.do※ 학부 재학생은 학년별로 날짜 및 시간대를 구분하여 수강신청을 실시하므로, 수강신청학년 반드시 확인붙임 1. 2024학년도 제2학기 수강신청 기본계획 1부.2. 수강신청 관련 주요 안내 사항 1부.3. 2024학년도 교양 교과목 현황 1부.4. 연합교양대학 강좌 수강 안내 1부.5. 수강신청 관련 신청 서식 각 1부.
# 212: □ 휴학 신청○ 학기 초(9월 첫째 주) 졸업예정자로 생성된 자는 2차 휴학 신청기간(2024. 9. 2. ~ 11. 26.)에 휴학 신청이 불가능하므로, 졸업예정자에서 제외 요청(학사서비스센터, 학사지원과) 후 휴학 신청 가능※1차 휴학 신청기간(2024. 8. 1. ~ 8. 30.)에는 별도 제외 요청 없이 신청 가능○ 일반휴학 신청 후 휴학 취소할 경우 기간 내 1회에 한하여 본인이 직접 통합정보시스템에서 취소 가능, 다시 휴학 신청할 경우 학사서비스센터에 방문하여야 함○ 전문연구요원 또는 산업기능요원으로 입영할 학생은 휴학 신청기간에 일반휴학을 한 후 입대휴학으로 대체하여야 함○ 휴학 신청 전에 도서관 대출 도서를 반납하여야 휴학이 허가됨□ 등록금(장학금) 관련○ 등록금을 납부하고 휴학한 자의 등록금은 본인 의사에 따라 반환하거나 복학하는 최초 학기로 이월 가능※ 휴학 신청 완료 후, 등록금 반환을 원하는 경우 통합정보시스템 상 【등록금반환신청(휴학)】메뉴에서 직접 등록금 반환 신청 진행※ 2024. 9. 1.(일) 이후 휴학 및 등록금 반환 신청할 경우 등록금 전액을 반환받지 못하고 복학 시 등록금 전액을 납부해야 하므로, 신중하게 등록금 반환 선택※ 자세한 사항은 재무과(042-821-5133, 5138)로 문의○ 2024학년도제2학기 장학금 수혜 대상자가 휴학할 경우에는 반드시 등록금을 납부하고, 등록처리 확인 후 휴학하여야 장학금 혜택을 받을 수 있음(등록금 미납 후 휴학 시 장학생 선발 무효/전액 장학생도 납부금액은‘0원’이라도 등록 확인 후 휴학해야함, 즉등록기간 종료 후 포털에서 등록완료 확인 후 휴학)○ 휴학하여 이미 등록금을 반환받은 경우에는 휴학취소 불가□ 복학 신청 및 휴학 연장○ 휴학 종료일 이전에 소정의 절차에 따라 정해진 기간 내에 복학 또는 휴학 연장을 하지 않으면 학칙 제37조에 따라미복학 제적됨○ 외국인 휴학자 및 창업 휴학자의 복학은 일반 학생의 복학 절차와 동일□ 수강신청○ 수강신청 여부와 관계없이 휴학 또는 복학할 경우 반드시 휴‧복학 신청을 별도로 해야 함※ 수강신청을 하지 않는다고 자동 휴학 처리되거나, 수강신청을 했다고 자동 복학 처리되지 않음○ 수강신청하였으나, 미복학할 경우, 9월 1일자로 모든 수강신청 과목은 사라지며, 재량껏 수강신청을 다시해야하므로, 복학처리 되었는지 반드시 확인(본인은 신청했다고 생각하고 있으나 저장 등을 누르지 않아 복학처리 안된 사례가 많음)자세한 내용은 첨부문서로 확인바랍니다.
