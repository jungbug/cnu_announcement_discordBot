# %%
from IPython.display import display
import pandas as pd
import requests
from bs4 import BeautifulSoup
from info import urls

# %%
class Crawler:
    def __init__(self, base_url):
        self.base_url = base_url

    def get_html(self, url):
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        else:
            return None

    def fetch_posts(self):
        html = self.get_html(self.base_url)
        soup = BeautifulSoup(html, 'html.parser')
        return soup

# %%
class Parser:
    def __init__(self, soup):
        self.soup = soup
        self.posts = []

    def parse_post_list(self, base_url):
        rows = self.soup.find_all("tr")
        for row in rows:
            number = row.find('td', class_="b-num-box")
            title_box = row.find('div', class_="b-title-box")
            date = row.find('span', class_="b-date")
            writer = row.find('span', class_="b-writer")
            views = row.find('span', class_="hit")
            post_data = {'번호': number.get_text(strip=True) if number else '',
                         '제목': title_box.a.get_text(strip=True) if title_box and title_box.a else '',
                         "작성자": writer.get_text(strip=True) if writer else '',
                         '날짜': date.get_text(strip=True) if writer else '',
                         "조회수": views.get_text(strip=True) if views else '',
                         "본문링크": base_url + title_box.a['href'] if title_box and title_box.a else ''}
            self.posts.append(post_data)

    def parse_contents(self, post, content_soup):
        content = content_soup.find("div", class_="fr-view")
        post["내용"] = content.get_text(strip=True).strip() if content else ''

    def parse_images(self, post, content_soup):
        div = content_soup.find("div", class_="fr-view")
        img_tags = div.find_all('img')
        if img_tags:
            img_srcs = [img['src'] if 'src' in img.attrs and "https://homepage.cnu.ac.kr" in img['src'] else 'https://ai.cnu.ac.kr' + img['src'] for img in img_tags]
            post["이미지"] = ''.join(img_srcs) if len(img_srcs) == 1 else img_srcs
        else:
            post["이미지"] = None

# %%
class DataCleaner:
    def __init__(self, posts):
        self.posts = posts

    def clean_data(self):
        if self.posts:
            self.posts.pop(0)
        for post in self.posts:
            view = post["조회수"].replace("조회수", "").strip()
            post["조회수"] = view

# %%
class TableParser:
    def __init__(self, base_url):
        self.base_url = base_url

    def parse_html_table(self, table):
        rows = table.find_all("tr")
        table_data = []
        columns = []
        rowspan_dict = {}

        for i, row in enumerate(rows):
            tds = row.find_all(["td", "th"])
            row_data = []
            col_idx = 0
            while col_idx in rowspan_dict:
                if rowspan_dict[col_idx][1] > 0:
                    row_data.append(rowspan_dict[col_idx][0])
                    rowspan_dict[col_idx][1] -= 1
                    if rowspan_dict[col_idx][1] == 0:
                        del rowspan_dict[col_idx]
                    col_idx += 1
                else:
                    del rowspan_dict[col_idx]

            for td in tds:
                spans = td.find_all("span")
                ps = td.find_all("p")
                if spans:
                    cell_text = " ".join([span.get_text(strip=True) for span in spans])
                elif ps:
                    cell_text = " ".join([p.get_text(strip=True) for p in ps])
                else:
                    cell_text = td.get_text(strip=True)
                colspan = int(td.get("colspan", 1))
                rowspan = int(td.get("rowspan", 1))

                for _ in range(colspan):
                    row_data.append(cell_text)
                    if rowspan > 1:
                        rowspan_dict[col_idx] = [cell_text, rowspan - 1]
                    col_idx += 1

            if i == 0:
                columns = row_data
            else:
                while len(row_data) < len(columns):
                    row_data.append("")
                table_data.append(row_data)

        # Check if table_data and columns have the correct format and if columns contain meaningful data
        if len(columns) > 1 and all(len(row) == len(columns) for row in table_data) and len(table_data) > 0:
            # Check if columns contain actual text
            if any(column.strip() for column in columns):
                return pd.DataFrame(table_data, columns=columns)

        return None

    def find_valid_tables(self, soup):
        div = soup.find("div", class_="fr-view")
        if not div:
            return []

        tables = div.find_all("table")
        valid_tables = []
        seen_tables = set()

        for table in tables:
            nested_tables = table.find_all("table")
            if nested_tables:
                for nested_table in nested_tables:
                    table_str = str(nested_table)
                    if table_str not in seen_tables:
                        seen_tables.add(table_str)
                        df = self.parse_html_table(nested_table)
                        if df is not None:
                            valid_tables.append(df)
            else:
                table_str = str(table)
                if table_str not in seen_tables:
                    seen_tables.add(table_str)
                    df = self.parse_html_table(table)
                    if df is not None:
                        valid_tables.append(df)

        return valid_tables

    def table_main(self, post_url):
        soup = BeautifulSoup(Crawler(self.base_url).get_html(post_url), 'html.parser')
        tables = self.find_valid_tables(soup)
        dfs = []
        for table in tables:
            pd.set_option('display.max_colwidth', None)
            pd.set_option('display.width', None)
            pd.set_option('display.max_columns', None)
            dfs.append(table)
        return dfs

# %%
class NoticeCrawler:
    def __init__(self, base_url):
        self.base_url = base_url
        self.crawler = Crawler(base_url)
        self.soup = self.crawler.fetch_posts()
        self.parser = Parser(self.soup)
        self.cleaner = DataCleaner(self.parser.posts)
        self.table_parser = TableParser(base_url)

    def crawl(self):
        self.parser.parse_post_list(self.base_url)
        self.cleaner.clean_data()
        self.parse_contents_and_images()
        self.parse_tables()

    def parse_contents_and_images(self):
        for post in self.parser.posts:
            post_url = post["본문링크"]
            content_soup = BeautifulSoup(self.crawler.get_html(post_url), 'html.parser')
            self.parser.parse_contents(post, content_soup)
            self.parser.parse_images(post, content_soup)

    def parse_tables(self):
        for post in self.parser.posts:
            post_url = post["본문링크"]
            dfs = self.table_parser.table_main(post_url)
            if dfs:
                post["is_table"] = 1
                post["table"] = dfs
            else:
                post["is_table"] = 0
                post["table"] = None

    def display_tables(self):
        for post in self.parser.posts:
            if post["is_table"] == 1:
                for df in post["table"]:
                    display(df)

# %%
if __name__ == "__main__":
    url = urls["학사공지"]
    crawler = NoticeCrawler(url)
    crawler.crawl()
    for post in crawler.parser.posts:
        post_without_table = {k: v for k, v in post.items() if k != "table"}
        print(post_without_table)
    crawler.display_tables()
# Out:
# {'번호': '공지', '제목': '[★★★ 1학년 교과목 수강신청 안내 (본인이 직접 수강신청) ★★★]', '작성자': '조교 이희정', '날짜': '24.07.23', '조회수': '589', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=519785&article.offset=0&articleLimit=10', '내용': '1학년 수강신청 날짜 및 시간을 꼭 확인 하시고 아래 안내 사항 확인 후본인이 직접 수강신청하시기 바랍니다. (2학기부터는 학과에서 수강신청 해주지 않음)[1학년 수강 신청 교과목]이수구분교과목명교과목번호분반학점졸업요건수강신청 기간교양미적분학11151-7008003필수1학년 수강신청 기간8. 6.(화) 15:00～17:00인공지능과 미래사회1004-7003053필수전공선형대수1214-1003003필수어드벤처디자인1215-1002003필수컴퓨터프로그래밍21216-1002003필수본인이 교양에서1개 교과목 선택해서 수강신청*3예비 수강신청 기간7.29(월)~7.31(수) 09:00~18:00-본인이 교양에서1개 교과목 선택해서 수강신청*:한 학기 수강 학점은 총18학점으로 학과에서 지정한 교과목(15학점)외에나머지3학점은 교양 교과목에서 본인이 희망하는 교과목으로 수강신청,될 수 있으면 졸업 필수 교과목인 핵심교양(목록은 붙임 졸업요건에서 확인)으로 수강 신청-인공지능과미래사회: 2022학번부터 지정된 전문기초교양으로2021학번은 인공지능개론(분반 상관없음.)수강 해야 함.-미적분학1: 2023학번부터 필수, 2021~2022학번은 선택(본인학번의 졸업요건 확인)[유의사항 및 일정]1.미적분학1,인공지능과미래사회:지정된 분반은 인공지능학과 학생을 위하여 확보된 분반이지만 타과 학생이 수강신청 할 경우 여석 확보가 어려울 수 있으므로가급적 빨리(8. 6.(화) 15:00정원 열리자마자)수강신청 하여 주시기 바랍니다.2.예비수강신청: 7.29(월) ~ 7.31.(수) 09:00~18:00 (학과에서 지정한 위의5개 교과목은 예비수강신청 대상과목이 아님)3.수강신청기간: 8.5(월) ~ 8.9(금)4. 1학년 수강신청 기간: 8.6(화) 15:00 ~ 17:00[해당 공지사항 문의: 821-7456,담당조교:이희정]', '이미지': None, 'is_table': 1}
# {'번호': '공지', '제목': '2024 학생휴가 신청시 주의사항 안내', '작성자': '조교 김현수', '날짜': '24.06.11', '조회수': '408', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=515554&article.offset=0&articleLimit=10', '내용': '', '이미지': ['https://homepage.cnu.ac.kr/_attach/image/editor_image/2024/06/NwDkyvBCxVZNBtVsHePq0.jpg', 'https://homepage.cnu.ac.kr/_attach/image/editor_image/2024/06/XhXCqBrvbtxVBVufTdGz0.jpg', 'https://homepage.cnu.ac.kr/_attach/image/editor_image/2024/06/XKztRoPErgPbnajZGTuW0.jpg'], 'is_table': 0}
# {'번호': '공지', '제목': '학과 GPU 서버 사용 신청 안내', '작성자': '서무 담당 조교', '날짜': '24.03.13', '조회수': '696', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=508553&article.offset=0&articleLimit=10', '내용': '학과에서는 연구용 \xa0GPU 사용 신청이 필요한 학생들에게 개발 환경을 제공하고 있습니다.아래 링크로 신청 하여 주시고 매뉴얼도 꼭 읽어 보시기 바랍니다.[구글신청폼 링크] : https://forms.gle/eeDHBbeXztzEEAkm8', '이미지': None, 'is_table': 0}
# {'번호': '공지', '제목': '★★ 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내', '작성자': '조교 이희정', '날짜': '24.01.19', '조회수': '805', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=503557&article.offset=0&articleLimit=10', '내용': '2024학년도 교육과정 개편으로 인공지능개론 대체교과목 및 컴퓨터과학적사고 이수면제 안내 드립니다.1. 인공지능개론 교과목의 대체 교과목 (해당학번: 2021)-\u3000전문기초교양 교과목은 본인의 이후 교육과정에 있는 교과목을 이수할 경우 전문기초교양으로 인정받을 수 있으니 인공지능개론 교과목 수강이 어려운 학생은 2022학년도 이후 교육과정의 전문기초교양 교과목인 인공지능과미래사회 교과목을 수강하시기 바랍니다.2. \xa0컴퓨터과학적사고 교과목 이수면제 (해당학번: 2021~2023)- 컴퓨터과학적사고 교과목이 2024학년도 교육과정 개편으로 교양(전문기초교양)에서 지정 해지 되어 이전 교육과정 적용자(2018~2023) 모두 이수면제 처리 되었습니다.이수면제된 학점은 교양(핵심, 일반)과목으로 추가 이수하여 교양 졸업학점을 채우면 됩니다.', '이미지': None, 'is_table': 0}
# {'번호': '공지', '제목': '[중요] 컴퓨터프로그래밍1~3, 컴퓨터구조 교과목 학과별 운영으로 개설학과 이외 수강생 전공 불인정 안내', '작성자': '조교 이희정', '날짜': '23.01.30', '조회수': '1348', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=319395&article.offset=0&articleLimit=10', '내용': '2023학년도 1학기부터 개설되는 아래 교과목은 컴퓨터융합학부와 교과목명은 동일하나교과목번호를 다르게 지정하여 학과별로 교육내용을 차별화하여 교과목을 운영하여개설학과 이외 학생이 수강할 경우 전공으로 인정 받을 수 없으니아래교과목은 반드시 본인의 소속학과에 개설된 교과목만 수강신청 하시기 바랍니다.이외에 컴퓨터융합학부와 인공지능학과에 개설된 교과목 중 \xa0교과목명 및 교과목번호가 같은 교과목은 \xa0두 학과 학생 모두 전공으로 인정 받습니다.2021, 2022학번 중 위의 교과목을 이수하지 않은 학생은2023년 이후에 인공지능학과에 개설 된 \xa0교과목을 수강하시면 됩니다.(본인의 교육과정 적용년도에 교과목번호가 달라도 인공지능학과에 개설된 교과목은 \xa0인공지능학과 학생이 수강할 경우 전공으로 인정 됨)', '이미지': 'https://ai.cnu.ac.kr/_attach/image/editor_image/2023/01/yZFtJqPTPPdfOPKQTOzF0.png', 'is_table': 0}
# {'번호': '공지', '제목': '충남대학교 백마인턴십 수강학생 전공학점 인정 등 안내', '작성자': '조교 김현수', '날짜': '23.01.03', '조회수': '1521', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=317481&article.offset=0&articleLimit=10', '내용': '□ 백마인턴십: 충남대학교와 사회의 각 기업(관)이 공동으로 참여하여 산업체 현장에서 학생에게 실무교육 및 실습을 실시하는 산학협력 교육과정자세한 내용은 붙임문서로 꼭 확인하기 바랍니다.* 복수전공. 부전공하는 타과 학생은 백마인턴십을 전공으로 인정하지 않습니다.전공 수업을 통해 학점을 채우기 바랍니다.* 우리 학과(컴융. 인공)학생이 컴융. 인공지능학과를 상호 복수.부전공 할 경우 백마인턴십을 복수.부전공으로 인정하지 않습니다. \xa0주전공에서만 전공학점으로 인정합니다.가. 교과과정* 졸업을 위한 학점인정을 계획하는 경우, 계절학기 백마인턴은 3학점만 신청가능.교과목명실습기간인정학점백마인턴십\xa0Ⅲ-1,\xa0Ⅲ-2,\xa0Ⅲ-3,\xa0Ⅲ-44주3학점백마인턴십\xa0Ⅰ-1,\xa0Ⅰ-2,\xa0Ⅰ-38주6학점백마인턴십II1학기18학점□ 실습시간 및 장소ㅇ 실습일수: 실제 출근일이 4주 20일, 8주 40일, 학기제 일 8시간 75일(주40시간 이내)이 되도록 실습 수행※실습일수 미충족 시 학생 학점 이수 불가※ 과정은 실습기관별 연말·연시 휴일을 반영하여 종료일 설정□ 백마인턴십 담당 선생님: 821-6169나. 참여대상 : 신청일 기준 4학기 이상 이수한 재학생 및 휴학생다. 신청방법 : 통합정보시스템-인턴십신청* 컴퓨터융합학부. 인공지능학과 전공자에 한하여 전공학점 인정되는 경우는- 1회에 한하여 인정(1회가 18학점 학기제이든 6학점 또는 3학점 계절제이든 1회만 인정)- 6학점 계절제 백마인턴십을 2번 이수하여도 1회(6학점)만 인정. 합산 불가- 6개 학기 학점사정, 졸업 사정 등에서 담당 선생님이 이수구분 정정함.- 부복수전공을 이수하는 타학과 학생이 컴퓨터관련 인턴십을 하여도 부복수이수학점으로 인정되지 않음.(본인 소속의 전공으로 인정되는지는 소속학과에 문의 필수)- 소프트웨어중심대학 사업단에서 백마인턴십과 함께 추진하여 인턴십 등으로 연계할 경우, 최대 24학점 인정.매학기 공지되는 백마인턴십 운영계획을 잘 확인하고 신청하기 바랍니다.', '이미지': None, 'is_table': 1}
# {'번호': '공지', '제목': '[★★★ 졸업요건]  프로젝트교과목 필수 이수 안내', '작성자': '조교 이희정', '날짜': '22.01.27', '조회수': '1804', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=287509&article.offset=0&articleLimit=10', '내용': '인공지능학과 내규에 따른2021학년도 이후 입학자(교육과정적용연도포함)들의\xa0졸업요건에 해당되는 사항입니다. (2021학년도 입학자 포함)1. 프로젝트 교과목 필수 이수- 인공지능학과 학생은모든 프로젝트 교과목 의무 수강을 통하여 최소한 1년에 1건 이상의 팀 프로젝트를 수행하여 졸업시까지 최소 3건 이상의 실무 프로젝트를 수행 하는 것을 목적으로 한다(졸업요건: 1년에 1개 교과목 이상 이수, 최소 3개 교과목 이수 완료)교과목명개설 학년-학기어드벤처디자인1-2기초프로젝트랩2-1, 2-2심화프로젝트랩3-1, 3-2종합설계14-1종합설계24-2', '이미지': None, 'is_table': 1}
# {'번호': '공지', '제목': '2022학년도 교양영어 교육과정 개편 안내(2021학년도 이전 입학자 포함)', '작성자': '조교 이희정', '날짜': '21.12.30', '조회수': '1330', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=285136&article.offset=0&articleLimit=10', '내용': '', '이미지': ['https://ai.cnu.ac.kr/_attach/image/editor_image/2021/12/NCAdwanSiwpYfHffGIuw.jpg', 'https://ai.cnu.ac.kr/_attach/image/editor_image/2021/12/zZzWqtvQTyFasjTQdRbs.jpg', 'https://ai.cnu.ac.kr/_attach/image/editor_image/2021/12/HyBhvGbtpTNVjVjdqYCw.jpg', 'https://ai.cnu.ac.kr/_attach/image/editor_image/2021/12/ofxlKnAefsuPzzBnlEcD.jpg'], 'is_table': 0}
# {'번호': '228', '제목': '컴퓨터융합학부, 인공지능학과 교차 수강신청 허용 교과목 없음', '작성자': '조교 이희정', '날짜': '24.08.08', '조회수': '29', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=521626&article.offset=0&articleLimit=10', '내용': '컴퓨터융합학부, 인공지능학과 교차 수강신청 허용 교과목은 없습니다.(합반 운영 교과목 제외)단 수강신청하지 못하여 졸업에 문제가 발생한 경우학과사무실로 연락하여 주시기 바랍니다.문의전화: 042-821-7456', '이미지': None, 'is_table': 0}
# {'번호': '227', '제목': '2학기 2차 국가장학금 신청 안내', '작성자': '조교 김현수', '날짜': '24.08.08', '조회수': '32', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=521598&article.offset=0&articleLimit=10', '내용': '', '이미지': 'https://ai.cnu.ac.kr/_attach/image/editor_image/2024/08/heTjMACteESWdgQmmFtD0.jpg', 'is_table': 0}
# {'번호': '226', '제목': '2024학년도 2학기 교내장학생 선발 서류 제출안내(이메일 제출 후 원본 제출 기한 확인)', '작성자': '조교 김현수', '날짜': '24.08.06', '조회수': '37', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=521546&article.offset=0&articleLimit=10', '내용': '모든 장학은 7개학기 이하 이수자 대상입니다(8개학기 이수자로 9개학기 등록시는 장학대상 아님)*장학생 선발 중이니 휴학하지 마세요.선발하다보면 장학금을 받을 수 있는 학생이 휴학을 해서 탈락하는 경우를 많이 봅니다. 안타까워요.- 등록금 납부기간에 본인 장학 확인가능: \xa08월 20-23일 고지서 출력하여 장학금 확인, 포털에서도 확인 가능- 장학금 전액 받는 학생도 통합정보시스템에 등록 완료로 확인 한 후 휴학하기 바랍니다.- 전액 수혜자가 아닌 경우는 차액을 납부해야 장학금이 유효합니다. 미등록 휴학시 장학금 소멸됩니다.(군휴학도 8월 말 휴학 권장)2024년도 2학기 등록금을 위한 장학금입니다.직전학기 취득학점 15학점(7학기자는 12학점) 이상인 학생 중,등록금 미납 후 휴학하면, 장학금은 소멸되며,특히 2학기 말에 추가로 장학생을 10명 가까이 선발할 때, 등록금 납부 휴학자는 선발 대상자가 될 수 있으나, 미납한 학생은 선발에서 제외됩니다.또한 연락불가, 응답 없음 등으로 본인 계좌를 확인할 방법이 없으면 지급 불가하니, 본인 계좌를 포털에 입력해두는 방법도 확인하기 바랍니다.국외 여행, 어학연수, 군대 입대로 인해 연락이 불가 할 것 같은 학생은 포털시스템 내 개인 계좌정보를 미리 입력해두면 장학금을 놓치지 않을 수 있습니다.(절대사항 아님)(자료실 장학으로 검색하면 입력방법 안내하였음)가능하다면 등록금 납부 후 휴학 권장합니다.- 교내 우수, 격려는 학과에서 성적 등으로 선발하므로 제출 서류는 없습니다.(성적우수장학금 가산점 신청은 마감됨. 학사공지 다른 글에서 확인)- 보훈, 영탑, 외국어우수(영어는 원본 제출), 새터민 등에 해당되는 경우 제출장학금 신청은 먼저1. 어떤 장학금을 신청할지 이메일로 알려주세요(podo@cnu.ac.kr): 8월 7일(수)까지2. 외국어우수 장학금을 포함하여 보훈, 새터민, 학석사 연계과정 합격자는 장학서류, 증빙서류를 준비하여 이메일로 보내주세요(사인 누락 주의): 8월 8일(목) 오전 9시까지3. 외국어우수 장학금 원본제출: 8월 8일(목) 오후 3시까지 학과사무실로 제출(원본 미제출시 장학생 선발 불가)메일 발송 후 1시간 이내 회신이 없으면 학과로 전화하여 확인 받으세요(821-6651)2학부 장학금별 선발기준 (붉은 글씨만 학생이 신청가능)구분명칭장학금액*선발기준직전학기평균평점인원비고대학추천**성적장학금성적우수등록금 전액성적우수자 및 학과 기준 적용3.25\xa0이상총장이 정하는 인원교내우수ㅇ격려등록금 일부\xa0C급성적우수자2.25\xa0이상〃교내격려ㅇ복지장학금백마등록금 일부국가장학금 기준 준용※\xa0단,\xa0국가\xa02유형 대상자는 등록금의\xa015%(예정)\xa0지원※\xa0이연자(등록유효복학자),\xa0수업연한초과자는 선발대상에서 제외좌동적격자영탑A등록금 전액장애의 정도가 심한 장애인(기존 장애1급～장애3급 학생)2.75\xa0이상〃ㅇ영탑B등록금 일부\xa0A급장애의 정도가 심하지 않은 장애인(기존 장애4급～장애6급 학생)2.75\xa0이상〃ㅇ특별장학금체육특기자등록금 전액체육진흥원 추천자1.75\xa0이상적격자ㅇ복수학위등록금 전액(4개 학기)국제교류본부장 추천자3.50\xa0이상(전 학기 평점)〃외국어성적우수등록금 일부\xa0A급TOEIC, TOEFL\xa0성적우수자(ETS\xa0주관)•TOEIC 900점 이상•TOEFL iBT 102점 이상※\xa0자격취득일부터\xa01년 이내 성적,재학 중\xa01회*만 수혜 가능*\xa0단,\xa0본교 출신 편입생이 동 장학금을 기수혜 한 경우에도,\xa0편입 후\xa01회 수혜 가능.\xa0편입생의 경우,\xa0편입 후 취득한 성적에 한함[ʹ23. 8. 1.～ ʹ24 7. 31.\xa0응시일자만 해당]※단,\xa0휴학학기에 등록금을 기납부한\xa0복학생(등록유효복학생)은 선발대상에서 제외※\xa0수업일수\xa01/3선\xa0(’24. 10. 11.)\xa0이내신청에 한해 지원2.75\xa0이상〃ㅇ외국인\xa0(6.25\xa0유엔참전용사 후손)등록금전액(정규학기)6.25\xa0유엔참전용사 후손(직계비속)임이확인된 외국인 유학생(국제교류본부 추천자)※\xa0해당자가 있는 경우 각 대학에서는 국제교류본부로 추천2.50이상〃외국인(학부)등록금 일부\xa0B급외국인 유학생※\xa0국적이 대한민국인 경우 제외2.75\xa0이상〃ㅇ외국인(복수학위3+1)등록금 일부아시아권 교류대학 복수학위(3+1)참가자2.25이상총장이정하는 인원보훈등록금 전액(정규 학기)국가유공자 본인 및 자녀※\xa0본인은 장학 기준 성적 및 지급학기 제한 없음1.51\xa0이상적격자새터민등록금 전액(정규 학기)북한이탈주민 본인 및 자녀※\xa0본인은 직전 두 학기 평균 성적이\xa0각각\xa01.51\xa0미만인 경우 장학금 지원 제한1.51\xa0이상〃학생활동등록금 전액또는 일부총학생회 및 단과대 학생회 간부 등2.25\xa0이상총장이 정하는 인원ㅇ학석사연계과정(학부)학업장려금(학부과정 전체학기3회 이내매 회150만원)학·석사연계과정 계속 유지자로\xa0학부과정 매학기 이수 이후 지급하되,이수학기 포함 전체 성적 평균 평점이3.75이상인 자3.75\xa0이상〃미래학업장려금일 부성적우수자(별도기준)3.50이상〃ㅇ장학명제출서류제출기한제출장소영탑장학금신청서,\xa0장애인증명서상단 내용 확인(시간 엄수)학과 사무실외국어성적우수장학금신청서, TOEIC, TOEFL\xa0성적증명서진위여부확인서(출력방법 첨부파일 확인)재학중 1회이므로 신중하게 신청.보훈, 새터민,학석사연계과정장학금신청서[단, 보훈,새터민 신규자는 대학수업료등 면제대상자증명서(교육지원대상자증명서) 추가 제출]', '이미지': None, 'is_table': 1}
# {'번호': '225', '제목': '최신AI특강2 교과목 전 학년 수강 가능 안내', '작성자': '조교 이희정', '날짜': '24.08.05', '조회수': '157', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520973&article.offset=0&articleLimit=10', '내용': '인공지능학과 최신AI특강2 교과목은 4학년 인공지능학과 개설 교과목이지만학년, 학과 제한 없이 수강 가능하다고 하니AI에 관심 있는 학생의 많은 참여 바랍니다.', '이미지': None, 'is_table': 0}
# {'번호': '224', '제목': '2024년도 2학기 보훈(가족)장학 신청 안내', '작성자': '조교 김현수', '날짜': '24.08.01', '조회수': '226', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520687&article.offset=0&articleLimit=10', '내용': '2024학년도 2학기 대전지방보훈청의 보훈가족장학(학부) 및 보훈장학(대학원생) 선발 계획을 안내하오니, 해당학생은 아래 내용을 확인하고 신청하기 바랍니다.가. 신청대상 및 자격1)보훈가족장학(학부생)- 신청대상: 6·25전몰군경자녀의 자녀로서 대학 등에 재학 중인 자- 신청자격: 대학교 재학자로직전학기 성적이70점이상인 자(신입생은 성적기준 제외)- 제외대상: 국가유공자의 전공사상 시기가 6·25전쟁이 아닌 경우, 학칙에서 정한 수업연한 초과자,당해 학기에 본인이 납부한 수업료가 없는 경우(타 장학금 수령 포함)2)보훈장학(대학원생)- 신청대상: 국가보훈관계 법령에 따라 교육지원대상자 중 본인 및 전몰․순직․사망배우자, 전상․공상․전몰․순직․재해부상․재해사망군경의 자녀(부모가 모두 사망하고 35세 미만인 경우에만 해당)- 신청자격: 대학원 석·박사 과정 재학 중인 자로직전학기 성적이80점 이상인 자,\xa02개 학기 이상의 학위과정 재학자는 하나의 과정만 신청 가능- 제외대상: 정규 첫 학기, 학칙으로 정한 해당과정 수업연한 초과자(단, 이미 지원받은 경우 이전학교(학위과정)에서 면제받은 수업연한을 제외하고 남은 수업연한 내), 연구과정 및 해외유학 과정3) 신청기간: 2024. 9. 2.(월) ~ 10. 1.(화)4) 신청방법: 본인 직접 신청5) 신청서 접수 및 문의처: 대전지방보훈청 보훈과(☎ 042-280-1135)붙임 2024. 2학기 보훈(가족)장학 신청 안내문(신청 서식 포함)', '이미지': None, 'is_table': 0}
# {'번호': '223', '제목': '제 4회 삼성 AI/CE Challenge 안내 (공모 기간 : 8/1~9/13)', '작성자': '조교 김현수', '날짜': '24.07.31', '조회수': '230', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520592&article.offset=0&articleLimit=10', '내용': '', '이미지': 'https://ai.cnu.ac.kr/_attach/image/editor_image/2024/07/RHCdHrtPJSVARgvAEhmL0.jpg', 'is_table': 0}
# {'번호': '222', '제목': '2024학년도 1학기 학생 자치활동 참여자 중 장학금 수혜대상자 확인 안내', '작성자': '조교 김현수', '날짜': '24.07.31', '조회수': '205', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520585&article.offset=0&articleLimit=10', '내용': '2024학년도 1학기에 아래 지원대상의 직책을 맡아 1학기를 완주한 학생이 있다면 학과로 연락주세요.해당자 : 학번, 이름, 연락처, 아래 구분과 지원대상의 직책 기재 후 podo@cnu.ac.kr로 제출단대별로 명단을 받았으나(우리학과는 없음), 누락되거나 변동된 경우가 있을가하여 확인합니다.이메일 제출기한: 8월 4일(일)까지이메일로 제출하고, 확인이 되며느 8월 5일까지 기재된 연락처로 전화 및 이메일 회신합니다. 회신 이메일 꼭 확인하고, 신청서 및 추천서를 제출하면 됩니다.', '이미지': 'https://homepage.cnu.ac.kr/_attach/image/editor_image/2024/07/NtzfwrhHbtkGlArMONGz0.png', 'is_table': 0}
# {'번호': '221', '제목': '2024학년도 1학기 교내 장학생 추가 2차 선발 (문자 수신자 확인용)', '작성자': '조교 김현수', '날짜': '24.07.29', '조회수': '320', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520413&article.offset=0&articleLimit=10', '내용': '2024학년도 1학기 장학생 선발 후 국가장학금 등 기타 장학으로 변경되어, 교내 장학 예산이 남게되면 추가 장학생을 선발합니다.1. 대상: 재학생 중 학과 기준에 따라 선발휴학생 중 등록금 납부자 중 기준에 따라 선발2. 선발결과: 학과 별 배정인원에 따라 선발하고, 대상자에게 문자 안내함본 공지사항은 문자 수신자가 스미싱 문자가 아님을 확인해주기 위한 공지입니다.추가 선발을 위한 신청은 받지 않습니다.본인 계좌 확인되면 본 공지는 삭제함', '이미지': None, 'is_table': 0}
# {'번호': '220', '제목': '[3학년] 실무프로젝트랩3 교과목 수강 제한 안내', '작성자': '조교 이희정', '날짜': '24.07.29', '조회수': '234', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520389&article.offset=0&articleLimit=10', '내용': '실무프로젝트랩3 교과목은 기업 연계 교과목으로수강신청 대상자는 카카오테크 캠퍼스 3기 학생 또는 CNU SW아카데미 5기 참여 학생입니다.2024학년도 2학기부터 수강신청 방법 또한기존 학과 일괄 수강신청에서 학생 직접(개별) 수강신청,학과 수강취소에서 학생 직접(개별) 수강취소로 변경되었으니 참고하여 주시기 바랍니다.', '이미지': None, 'is_table': 0}
# {'번호': '219', '제목': '2024학년도 제2학기 SW교양교과목 수강 안내', '작성자': '조교 이희정', '날짜': '24.07.25', '조회수': '316', '본문링크': 'https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=520125&article.offset=0&articleLimit=10', '내용': '소프트웨어중심대학사업단에서는 대학SW·AI교육을 통한 융합인재 양성을 위해SW기초 역량 교육을 아래와 같이 제공하고 있습니다.컴퓨터융합학부 및 인공지능학과 학생은인공지능과미래사회(03~05분반),파이썬 프로그래밍,인공지능융합기초 교과목을 제외한 나머지 교과목은 수강 불가로수강신청 시 유의 하시기 바랍니다.해당 과목 외 수강신청 기간에 수강신청이 가능하여 수강신청 했더라도개강 시 담당교수님의 수강 제한이 있으니 참고하시기 바랍니다.2024학년도\xa02학기\xa0SW교양교과목 운영 계획과목명(과목번호)분반수강신청 대상비고컴퓨터과학적사고(1004-7002)00~03전계열(권장계열\xa0:\xa0이공계열)이론(콘텐츠 활용) +\xa0실습(실시간 원격,\xa0파이썬기초)인공지능과 미래사회(1004-7003)00~02전계열콘텐츠 활용 원격 강의시간표 미지정03~05컴퓨터융합학부,인공지능학과 전용 분반인공지능융합기초(1004-7004)00~02전계열대면 강의파이썬 프로그래밍(1004-7005)00~01전계열이론(콘텐츠 활용) +\xa0실습(실시간 원격)02전계열대면 강의데이터분석 입문과활용(1004-7006)00전계열이론(콘텐츠 활용) +\xa0실습(실시간 원격)컴퓨터 이해와 활용(1004-7007)00전계열(권장계열\xa0:\xa0인문/사회/예체능)대면 강의01~03전계열(권장계열\xa0:\xa0인문/사회/예체능)콘텐츠 활용 원격 강의,시간표 미지정04전계열콘텐츠 활용 원격 강의시간표 미지정(외국인 전용 분반)정보보호 입문과활용(1004-7008)00전계열대면 강의웹프로그래밍기초(1004-7009)00전계열이론(콘텐츠 활용) +\xa0실습(실시간 원격)C프로그래밍기초(1004-7010)00전계열이론(콘텐츠 활용) +\xa0실습(실시간 원격)※\xa0「컴퓨터 이해와 활용」,\xa0「인공지능과 미래사회」\xa0교과목 등 일부 분반은\xa01학년 수강 정원 비율을 높여 운영□\xa0소프트웨어중심대학사업단 주관\xa0SW교양교과목 강좌 운영 계획수강 제한 사항-\xa0파이썬프로그래밍,\xa0웹프로그래밍기초, C프로그래밍기초\xa0:\xa0프로그래밍 관련 타 교과목에서 해당 프로그래밍 언어를 배운 학생은 수강 불가- 컴퓨터융합학부, 인공지능학과 : 인공지능과 미래사회(03~05분반), 파이썬 프로그래밍, 인공지능융합기초 교과목 외 수강 불가운영방법\xa0:\xa0대면강의/원격강의(실시간/콘텐츠활용)\xa0등 교과목별로 상이평가방법\xa0:\xa0절대평가', '이미지': None, 'is_table': 1}
#                           이수 구분                          교과목명  \
# 0                            교양                        미적분학 1
# 1                            교양                    인공지능과 미래사회
# 2                            전공                          선형대수
# 3                            전공                       어드벤처디자인
# 4                            전공                    컴퓨터프로그래밍 2
# 5  본인이 교양에서 1 개 교과목 선택해서 수강신청 *  본인이 교양에서 1 개 교과목 선택해서 수강신청 *
#
#                           교과목번호                            분반 학점 졸업 요건  \
# 0                     1151-7008                            00  3    필수
# 1                     1004-7003                            05  3    필수
# 2                     1214-1003                            00  3    필수
# 3                     1215-1002                            00  3    필수
# 4                     1216-1002                            00  3    필수
# 5  본인이 교양에서 1 개 교과목 선택해서 수강신청 *  본인이 교양에서 1 개 교과목 선택해서 수강신청 *  3
#
#                                       수강신청 기간
# 0       1 학년 수강신청 기간 8. 6.( 화 ) 15:00 ～ 17:00
# 1
# 2
# 3
# 4
# 5  예비 수강신청 기간 7.29( 월 )~7.31( 수 ) 09:00~18:00
#                        교과목명 실습기간  인정학점
# 0  백마인턴십 Ⅲ-1, Ⅲ-2, Ⅲ-3, Ⅲ-4   4주   3학점
# 1       백마인턴십 Ⅰ-1, Ⅰ-2, Ⅰ-3   8주   6학점
# 2                   백마인턴십II  1학기  18학점
#       교과목명  개설 학년-학기
# 0  어드벤처디자인       1-2
# 1  기초프로젝트랩  2-1, 2-2
# 2  심화프로젝트랩  3-1, 3-2
# 3    종합설계1       4-1
# 4    종합설계2       4-2
#         구분                    명칭                       장학금액 *  \
# 0   성적 장학금                  성적우수                       등록금 전액
# 1   성적 장학금                    격려                    등록금 일부 C급
# 2   복지 장학금                    백마                       등록금 일부
# 3   복지 장학금                   영탑A                       등록금 전액
# 4   복지 장학금                   영탑B                    등록금 일부 A급
# 5   특별 장학금                 체육특기자                       등록금 전액
# 6   특별 장학금                  복수학위               등록금 전액 (4개 학기)
# 7   특별 장학금               외국어성적우수                    등록금 일부 A급
# 8   특별 장학금  외국인 (6.25 유엔참전용사 후손)                   등록금전액 정규학기
# 9   특별 장학금               외국인(학부)                    등록금 일부 B급
# 10  특별 장학금         외국인 (복수학위3+1)                       등록금 일부
# 11  특별 장학금                    보훈               등록금 전액 (정규 학기)
# 12  특별 장학금                   새터민               등록금 전액 (정규 학기)
# 13  특별 장학금                  학생활동                 등록금 전액 또는 일부
# 14  특별 장학금          학석사연계과정 (학부)  학업장려금 학부과정 전체학기 회 이내 매 회 만원
# 15  특별 장학금                    미래                    학업장려금 일 부
#
#                                                                                                                                                                                                                                                                                                           선발기준  \
# 0                                                                                                                                                                                                                                                                                             성적우수자 및 학과 기준 적용
# 1                                                                                                                                                                                                                                                                                                        성적우수자
# 2                                                                                                                                                                                                                            국가장학금 기준 준용 ※ 단, 국가 2유형 대상자는 등록금의 15%(예정) 지원 ※ 이연자( 등록유효복학자 ), 수업연한초과자는 선발대상에서 제외
# 3                                                                                                                                                                                                                                                                             장애의 정도가 심한 장애인 (기존 장애1급～장애3급 학생)
# 4                                                                                                                                                                                                                                                                         장애의 정도가 심하지 않은 장애인 (기존 장애4급～장애6급 학생)
# 5                                                                                                                                                                                                                                                                                                    체육진흥원 추천자
# 6                                                                                                                                                                                                                                                                                                  국제교류본부장 추천자
# 7   TOEIC, TOEFL 성적우수자(ETS 주관) •TOEIC 900점 이상 •TOEFL iBT 102점 이상 ※ 자격취득일부터 1년 이내 성적,  재학 중 1회*만 수혜 가능   * 단, 본교 출신 편입생이 동 장학금을 기수혜 한 경우에도, 편입 후 1회 수혜 가능. 편입생의 경우, 편입 후 취득한 성적에 한함 [ ʹ23. 8. 1.～ ʹ24 7. 31. 응시일자만 해당 ] ※ 단, 휴학학기에 등록금을 기납부한 복학생 (등록유효복학생) 은 선발대상에서 제외 ※ 수업일수 1/3선 (’24. 10. 11.) 이내  신청에 한해 지원
# 8                                                                                                                                                                                                                               6.25 유엔참전용사 후손(직계비속)임이 확인된 외국인 유학생(국제교류본부 추천자) ※ 해당자가 있는 경우 각 대학에서는 국제교류본부로 추천
# 9                                                                                                                                                                                                                                                                                    외국인 유학생 ※ 국적이 대한민국인 경우 제외
# 10                                                                                                                                                                                                                                                                                          아시아권 교류대학 복수학위 참가자
# 11                                                                                                                                                                                                                                                                   국가유공자 본인 및 자녀 ※ 본인은 장학 기준 성적 및 지급학기 제한 없음
# 12                                                                                                                                                                                                                                                북한이탈주민 본인 및 자녀 ※ 본인은 직전 두 학기 평균 성적이 각각 1.51 미만인 경우 장학금 지원 제한
# 13                                                                                                                                                                                                                                                                                         총학생회 및 단과대 학생회 간부 등
# 14                                                                                                                                                                                                                                             학 석사연계과정 계속 유지자로 학부과정 매학기 이수 이후 지급하되 이수학기 포함 전체 성적 평균 평점이 이상인 자
# 15                                                                                                                                                                                                                                                                                                 성적우수자(별도기준)
#
#             직전학기 평균평점          인원    비고 대학 추천 **
# 0             3.25 이상  총장이 정하는 인원  교내우수        ㅇ
# 1             2.25 이상           〃  교내격려        ㅇ
# 2                  좌동         적격자
# 3             2.75 이상           〃              ㅇ
# 4             2.75 이상           〃              ㅇ
# 5             1.75 이상         적격자              ㅇ
# 6   3.50 이상 (전 학기 평점)           〃
# 7             2.75 이상           〃              ㅇ
# 8              2.50이상           〃
# 9             2.75 이상           〃              ㅇ
# 10                 이상  총장이 정하는 인원
# 11            1.51 이상         적격자
# 12            1.51 이상           〃
# 13            2.25 이상  총장이 정하는 인원              ㅇ
# 14            3.75 이상           〃
# 15            3.50 이상           〃              ㅇ
#                 장학명  \
# 0                영탑
# 1           외국어성적우수
# 2  보훈, 새터민, 학석사연계과정
#
#                                                          제출서류  \
# 0                                              장학금신청서, 장애인증명서
# 1                                          재학중 1회이므로 신중하게 신청.
# 2  장학금신청서  [단, 보훈,새터민 신규자는 대학수업료등 면제대상자증명서(교육지원대상자증명서) 추가 제출]
#
#                제출기한    제출장소
# 0  상단 내용 확인 (시간 엄수)  학과 사무실
# 1
# 2
#                  과목명 (과목번호)     분반                 수강신청 대상  \
# 0      컴퓨터과학적사고 (1004-7002)  00~03                     전계열
# 1    인공지능과 미래사회 (1004-7003)  00~02                     전계열
# 2    인공지능과 미래사회 (1004-7003)  03~05  컴퓨터융합학부 , 인공지능학과 전용 분반
# 3      인공지능융합기초 (1004-7004)  00~02                     전계열
# 4     파이썬 프로그래밍 (1004-7005)  00~01                     전계열
# 5     파이썬 프로그래밍 (1004-7005)     02                     전계열
# 6   데이터분석 입문과활용 (1004-7006)     00                     전계열
# 7    컴퓨터 이해와 활용 (1004-7007)     00                     전계열
# 8    컴퓨터 이해와 활용 (1004-7007)  01~03                     전계열
# 9    컴퓨터 이해와 활용 (1004-7007)     04                     전계열
# 10   정보보호 입문과활용 (1004-7008)     00                     전계열
# 11     웹프로그래밍기초 (1004-7009)     00                     전계열
# 12     C프로그래밍기초 (1004-7010)     00                     전계열
#
#                                               비고
# 0   (권장계열 : 이공계열) 이론(콘텐츠 활용) + 실습(실시간 원격, 파이썬기초)
# 1                           콘텐츠 활용 원격 강의 시간표 미지정
# 2                         컴퓨터융합학부 , 인공지능학과 전용 분반
# 3                                          대면 강의
# 4                        이론(콘텐츠 활용) + 실습(실시간 원격)
# 5                                          대면 강의
# 6                        이론(콘텐츠 활용) + 실습(실시간 원격)
# 7                       (권장계열 : 인문/사회/예체능) 대면 강의
# 8       (권장계열 : 인문/사회/예체능) 콘텐츠 활용 원격 강의, 시간표 미지정
# 9                콘텐츠 활용 원격 강의 시간표 미지정(외국인 전용 분반)
# 10                                         대면 강의
# 11                       이론(콘텐츠 활용) + 실습(실시간 원격)
# 12                       이론(콘텐츠 활용) + 실습(실시간 원격)

# %%
def get_html(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        return None

def fetch_posts(base_url):
    html = get_html(base_url)
    soup = BeautifulSoup(html, 'html.parser')
    return soup

url = urls["학사공지"]
soup = fetch_posts("https://ai.cnu.ac.kr/ai/board/notice.do?mode=view&articleNo=503557&article.offset=0&articleLimit=10")

def parse_files(content_soup):
    total_file = []
    file_box = content_soup.find("div", class_="b-file-box")
    lis = file_box.find_all("li") if file_box else total_file == None
    if lis:
        for file_num, li in enumerate(lis):
            file_dict = {}
            file = li.find_all("a")
            file_dict["다운로드"] = "https://ai.cnu.ac.kr/ai/board/notice.do?" + file[0]["href"]
            file_dict["미리보기"] = "https://ai.cnu.ac.kr" + file[1]["href"]
            total_file.append(file_dict)
    return total_file

parse_files(soup)
# Out:
# []

# %%
'''if lis:
    for file_num, li in enumerate(lis):
        file_dict = {}
        file = li.find_all("a")
        file_dict["다운로드"] = "https://ai.cnu.ac.kr" + file[0]["href"]
        file_dict["미리보기"] = "https://ai.cnu.ac.kr" + file[1]["href"]
        total_file.append(file_dict)
if len(total_file) >= 2 or len(total_file) == 0:
    post["첨부파일"] = total_file
elif len(total_file) == 1:
    post["첨부파일"] = ''.join(str(d) for d in total_file)'''
